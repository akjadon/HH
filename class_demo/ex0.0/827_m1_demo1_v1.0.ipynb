# %% [markdown]
# # Predictive Analytics
# # Module 1 - Statistical Foundations
# ## Demo 1 - Data I/O & Data Types

# %% [markdown]
# ### Use-Case: Predict Future Sales

# %% [markdown]
# ### Load Data

# %%
import pandas as pd

# %%
items = pd.read_csv("C:\\Users\\anilj\\OneDrive\\Desktop\\ek\\PA\\1.StatisticalFoundations\\dataset\\items.csv")
shops = pd.read_csv("C:\\Users\\anilj\\OneDrive\\Desktop\\ek\\PA\\1.StatisticalFoundations\dataset\shops.csv")
cats = pd.read_csv("C:\\Users\\anilj\\OneDrive\\Desktop\\ek\\PA\\1.StatisticalFoundations\\dataset\\item_categories.csv")
train = pd.read_csv("C:\\Users\\anilj\\OneDrive\\Desktop\\ek\\PA\\1.StatisticalFoundations\\dataset\\sales_train.csv")

# %% [markdown]
# ### Look at the first five rows

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# ### Dimensions of Data

# %%
train.shape
# Out:
# (2935849, 6)

# %%
print("Categories:",cats.shape)
print("Items:",items.shape)
print("Shops:",shops.shape)
print("Train:",train.shape)
# Out:
# Categories: (84, 2)
# Items: (22170, 3)
# Shops: (60, 2)
# Train: (2935849, 6)

# %% [markdown]
# ### Data type for each attribute

# %%
train.dtypes
# Out:
# date               object
# date_block_num      int64
# shop_id             int64
# item_id             int64
# item_price        float64
# item_cnt_day      float64
# dtype: object
